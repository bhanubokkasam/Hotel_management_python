# %%
total_rooms=10 #declaring rooms
avail_rooms=10
res_rooms=0
r_no=[]

class hotel:#class hotel
    
    def details(self):#this for entering details
        self.name=input('enter your name: ')
        self.num=int(input('enter your mobile number: '))
        self.req_rooms=int(input('enter rooms required: '))
        self.duration=int(input('enter how many days you want to stay: '))
    
    def update_data(self):#fro updating details of available rooma
        global total_rooms
        global avail_rooms
        global res_rooms
        avail_rooms = total_rooms-self.req_rooms
        res_rooms+=self.req_rooms
        total_rooms=avail_rooms
        
    def room_details(self,r):#for checking room details not working
        r1=[]
        for i in range(0,len(r_no)):
            r1.append(r)
        
        for x in range(len(r1)):
            print( r1[x].r_no)

while True:# main code
    print('welcome to HOTEL BHANU')
    print('1. booking \n2.enquiry \n3.add \n4.exit')
    ch=int(input('select a number as above (1-3)'))
    
    if ch==1:# for booking
        print('available rooms are: ')
        print(avail_rooms)
        print('reserved rooms are')
        print(res_rooms)
        booking = int(input('enter 1 for booking: '))
        if booking ==1 :#giving details and changing data
            h=hotel()
            h.details()
            
            h.update_data()
            r_no.append(h)
            print('thanks for booking')
        else:
            break
    
    elif ch==2:#for enquiry
        print('Enquiry \n1 for search with customer name \n2 for search with room number \n3 for room availability \n4 for exit')
        enq=int(input('select from above choice: '))
        if enq==1: #for searching with name
            search_name=input('Enter name to search:-')
            i = 0
            while i < len(r_no):
                if(r_no[i].name==search_name):#checking equality of name
                    print(r_no[i].name)
                    print(r_no[i].num)
                    print(r_no[i].req_rooms)
                    print(r_no[i].duration)
                i += 1
                
    
        elif enq==2:
            h.room_details(r_no)
        elif enq==3:#for checking number of rooms available
            print('number of rooms available are', avail_rooms)
        else :
            break
    elif ch==3:#for adding customer just redirect to booking
        print('available rooms are: ')
        print(avail_rooms)
        print('reserved rooms are ')
        print(res_rooms)
        booking = int(input('enter 1 for booking: '))
        if booking ==1 :
            h=hotel()
            h.details()
            
            h.update_data()
            r_no.append(h)
            print('thanks for booking')
    else:
        break
# Out:
# welcome to HOTEL BHANU
# 1. booking
# 2.enquiry
# 3.add
# 4.exit
# select a number as above (1-3)1
# available rooms are:
# 10
# reserved rooms are
# 0
# enter 1 for booking: 1
# enter your name: bhanu
# enter your mobile number: 89625
# enter rooms required: 2
# enter how many days you want to stay: 1
# thanks for booking
# welcome to HOTEL BHANU
# 1. booking
# 2.enquiry
# 3.add
# 4.exit
# select a number as above (1-3)3
# available rooms are:
# 8
# reserved rooms are
# 2
# enter 1 for booking: 1
# enter your name: bhanu
# enter your mobile number: 588
# enter rooms required: 2
# enter how many days you want to stay: 1
# thanks for booking
# welcome to HOTEL BHANU
# 1. booking
# 2.enquiry
# 3.add
# 4.exit
# select a number as above (1-3)2
# Enquiry
# 1 for search with customer name
# 2 for search with room number
# 3 for room availability
# 4 for exit
# select from above choice: 3
# number of rooms available are 6
# welcome to HOTEL BHANU
# 1. booking
# 2.enquiry
# 3.add
# 4.exit
# ...
